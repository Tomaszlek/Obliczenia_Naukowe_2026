# %% [markdown]
# # Lista 1
# # Grupa A
# # Mateusz Izdebski & Tomasz Jarmoc

# %% [markdown]
# ## Definicja funkcji

# %%
import sympy as sp

x = sp.symbols('x')
function = -5 * x * (2 * x - 3) ** 1/5
