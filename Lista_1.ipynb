# %% [markdown]
# # Lista 1
# # Grupa A
# # Mateusz Izdebski & Tomasz Jarmoc

# %%
import sympy as sp

x = sp.symbols('x')
function = -5 * x * (2 * x - 3) ** 1/5

# %% [markdown]
# ### zadanie 1

# %% [markdown]
# ### zadanie 2

# %% [markdown]
# ### zadanie 3

# %% [markdown]
# ### zadanie 4

# %% [markdown]
# ### zadanie 5

# %% [markdown]
# ### zadanie 6

# %% [markdown]
# ### zadanie 7

# %%
# Wyznaczanie punktów przegięcia podanej funkcji
# Żeby to zrobic, trzeba policzyc pochodna 2 stopnia tej funkcji 
druga_pochodna = sp.diff(function, x, 2)

punkty_przegiecia_funkcji = sp.solve(druga_pochodna, x)
punkty_przegiecia_funkcji
# Out:
# []

# %% [markdown]
# Nie ma punktów przegięcia??? Możliwe, ale nie jestem pewien

# %% [markdown]
# ### zadanie 8

# %%
# Policzyć pole obszaru ograniczonego funkcja i prostymi y = 0, x = 2, x = 3
pole_pole_lyse_pole = sp.integrate(function, (x, 2, 3))
pole_pole_lyse_pole
# Out:
# -31/6

# %% [markdown]
# ### zadanie 9

# %% [markdown]
# ### zadanie 10

# %% [markdown]
# ### Zadanie 11

# %% [markdown]
# ### Zadanie 12

# %% [markdown]
# ### Zadanie 13
